# %% [markdown]
# # Analysis of White house Staff Salaries dataset

# %% [markdown]
# ## Load the dataset

# %%
import pandas as pd

pd.set_option("display.max_rows", 60)
pd.set_option("display.max_columns", 7)

# %%
FILEPATH = "https://raw.githubusercontent.com/mercybose/public_datasets/master/wh_staff_dataset.csv"

# %%
wh_df = pd.read_csv(FILEPATH)

# %% [markdown]
# ## View some rows

# %%
wh_df.shape
# Out:
# (10600, 7)

# %%
wh_df.head(60)
# Out:
#     year                        name  gender    status    salary  pay_basis  \
# 0   1997              Abedin,Huma M.  Female  Employee   27500.0  Per Annum
# 1   1997              Abrams,Lori E.  Female  Employee   35000.0  Per Annum
# 2   1997             Alcorn,Brian A.    Male  Employee   25000.0  Per Annum
# 3   1997         Allen,Jeannetta Pam  Female  Employee   22000.0  Per Annum
# 4   1997          Allison,Donna Tate  Female  Employee   27624.0  Per Annum
# 5   1997           Alston,Mildred C.  Female  Employee   47000.0  Per Annum
# 6   1997             Alterescu,Louis    Male  Detailee   73163.0  Per Annum
# 7   1997             Amador,Patricia  Female  Detailee   54629.0  Per Annum
# 8   1997      Amorsingh,Lucius Linus    Male  Employee   24858.0  Per Annum
# 9   1997               Anders,Brenda  Female  Employee   31000.0  Per Annum
# 10  1997          Anderson,Lori Lynn  Female  Employee   30000.0  Per Annum
# 11  1997                Attie,Eli G.    Male  Employee   70000.0  Per Annum
# 12  1997            Aversano,Gene T.    Male  Employee   24082.0  Per Annum
# 13  1997            Bachman,Robin J.  Female  Employee   45000.0  Per Annum
# 14  1997        Baer,Christine Klima  Female  Employee   43442.0  Per Annum
# 15  1997              Baer,Donald A.    Male  Employee  125000.0  Per Annum
# 16  1997            Bailey,Yvonne G.  Female  Employee   27964.0  Per Annum
# 17  1997               Baker,Kyle M.    Male  Employee   30000.0  Per Annum
# 18  1997          Balderston,Kris M.  Female  Detailee  108824.0  Per Annum
# 19  1997         Baldick,Nicholas R.    Male  Employee   60000.0  Per Annum
# 20  1997             Band,Douglas J.    Male  Employee   30000.0  Per Annum
# 21  1997          Barclay,Barbara A.  Female  Employee   53598.0  Per Annum
# 22  1997        Barksdale,Antoinette  Female  Detailee   71011.0  Per Annum
# 23  1997           Barnes,Beverly L.  Female  Employee   90000.0  Per Annum
# 24  1997           Barry,Kathleen A.  Female  Employee   25000.0  Per Annum
# 25  1997              Bass,Walker F.    Male  Employee   30000.0  Per Annum
# 26  1997            Bates,Melinda N.  Female  Employee   59000.0  Per Annum
# 27  1997              Bean,Eileen F.  Female  Employee   41866.0  Per Annum
# 28  1997          Beaubaire,David S.    Male  Employee   40000.0  Per Annum
# 29  1997       Bedwell,Wendy Lynette  Female  Employee   25897.0  Per Annum
# 30  1997                Belsky,David    Male  Employee   27000.0  Per Annum
# 31  1997        Bennett,Jacquelyn J.  Female  Employee   45000.0  Per Annum
# 32  1997            Berger,Samuel R.    Male  Employee  125000.0  Per Annum
# 33  1997             Berry,Marsha E.  Female  Employee   85000.0  Per Annum
# 34  1997             Beveridge,Susan  Female  Employee   31500.0  Per Annum
# 35  1997       Bianchi,Sarah Abigail  Female  Employee   40000.0  Per Annum
# 36  1997               Binns,Mary U.  Female  Employee   33792.0  Per Annum
# 37  1997               Bird,Debra D.  Female  Employee   42164.0  Per Annum
# 38  1997           Blinken,Antony J.    Male  Employee  100000.0  Per Annum
# 39  1997         Blocker,Ananias,III    Male  Employee   70000.0  Per Annum
# 40  1997             Blunt,Shenna C.  Female  Employee   22500.0  Per Annum
# 41  1997            Bohrer,George H.    Male  Employee   45997.0  Per Annum
# 42  1997           Bowles,Erskine B.    Male  Employee       1.0  Per Annum
# 43  1997             Breuer,Lanny A.    Male  Employee  107500.0  Per Annum
# 44  1997  Briggs,Patrick Edward Jude    Male  Employee   31500.0  Per Annum
# 45  1997              Bromberg,Emily  Female  Employee   80000.0  Per Annum
# 46  1997             Brophy,Susan A.  Female  Employee  110000.0  Per Annum
# 47  1997        Brown,Margueritte B.  Female  Detailee   83528.0  Per Annum
# 48  1997         Burkhardt,Daniel W.    Male  Employee   60000.0  Per Annum
# 49  1997         Button,Katharine M.  Female  Employee   30000.0  Per Annum
# 50  1997           Byrd,Kimberley J.  Female  Employee   23305.0  Per Annum
# 51  1997          Cameron,Rebecca A.  Female  Employee   35000.0  Per Annum
# 52  1997         Campbell,Frances L.  Female  Employee   44719.0  Per Annum
# 53  1997          Canter,Virginia R.  Female  Employee   92000.0  Per Annum
# 54  1997              Caplan,Phillip    Male  Employee   90000.0  Per Annum
# 55  1997        Capps,Laura Karolina  Female  Employee   34000.0  Per Annum
# 56  1997           Caramanica,Janice  Female  Detailee   56450.0  Per Annum
# 57  1997               Carey,Paul R.    Male  Employee   75000.0  Per Annum
# 58  1997       Carter,Cheryl M. Cole  Female  Employee   85000.0  Per Annum
# 59  1997          Castleman,Helen S.  Female  Employee   28500.0  Per Annum
#
#                                        position_title
# 0                                      OFFICE MANAGER
# 1                  DEPUTY DIRECTOR, WHITE HOUSE GIFTS
# 2                      ASSISTANT DIRECTOR FOR ADVANCE
# 3                                     STAFF ASSISTANT
# 4                      WHITE HOUSE TELEPHONE OPERATOR
# 5           SPECIAL ASSISTANT PERSONAL CORRESPONDENCE
# 6                                  ATTORNEY - ADVISOR
# 7                                  ATTORNEY - ADVISOR
# 8                      WHITE HOUSE TELEPHONE OPERATOR
# 9                                   RADIO COORDINATOR
# 10                   ASSISTANT TO THE PRESS SECRETARY
# 11  SPECIAL ASSISTANT TO THE PRESIDENT FOR COMMUNI...
# 12                      RECORDS MANAGEMENT TECHNICIAN
# 13                                         RESEARCHER
# 14                                  SPECIAL ASSISTANT
# 15  ASSISTANT TO THE PRESIDENT AND DIRECTOR OF STR...
# 16                     WHITE HOUSE TELEPHONE OPERATOR
# 17                                      SENIOR WRITER
# 18  SPECIAL ASSISTANT TO THE PRESIDENT FOR CABINET...
# 19                         EASTERN POLITICAL DIRECTOR
# 20                                    STAFF ASSISTANT
# 21    ADMINISTRATIVE ASSISTANT TO THE STAFF SECRETARY
# 22                                 ATTORNEY - ADVISOR
# 23               SENIOR ADVISOR TO THE CHIEF OF STAFF
# 24                                    STAFF ASSISTANT
# 25                          DEPUTY ASSOCIATE DIRECTOR
# 26  SPECIAL ASSISTANT TO THE PRESIDENT AND DIRECTO...
# 27  WHITE HOUSE TELEPHONE OPERATOR ASSISTANT SUPER...
# 28  SPECIAL ASSISTANT TO THE CABINET SECRETARY & D...
# 29                      RECORDS MANAGEMENT TECHNICIAN
# 30                                EDITORIAL ASSISTANT
# 31                                  FINANCIAL MANAGER
# 32  ASSISTANT TO THE PRESIDENT FOR NATIONAL SECURI...
# 33  DEPUTY ASSISTANT TO THE PRESIDENT & DIRECTOR O...
# 34                                 SENIOR CASE WORKER
# 35               ASSISTANT DIRECTOR FOR HEALTH POLICY
# 36                             CORRESPONDENCE ANALYST
# 37                                     OFFICE MANAGER
# 38  SPECIAL ASSISTANT TO THE PRESIDENT FOR STRATEG...
# 39  SPECIAL ASSISTANT TO THE PRESIDENT FOR LEGISLA...
# 40                   ADMINISTRATIVE SUPPORT ASSISTANT
# 41            SPECIAL PROJECTS ASSISTANT FOR PRINTING
# 42                    CHIEF OF STAFF TO THE PRESIDENT
# 43                   SPECIAL COUNSEL TO THE PRESIDENT
# 44          DEPUTY DIRECTOR OF PRESIDENTIAL INQUIRIES
# 45  DEPUTY ASSISTANT TO THE PRESIDENT & DEPUTY DIR...
# 46  DEPUTY ASSISTANT TO THE PRESIDENT & DEPUTY DIR...
# 47                       ASSISTANT FOR CORRESPONDENCE
# 48  DEPUTY DIRECTOR OF CORRESPONDENCE & PRESIDENTI...
# 49  ASSISTANT TO THE CHIEF OF STAFF TO THE FIRST LADY
# 50                     WHITE HOUSE TELEPHONE OPERATOR
# 51                                    STAFF ASSISTANT
# 52                         SUPERVISOR DATA ENTRY UNIT
# 53                 ASSOCIATE COUNSEL TO THE PRESIDENT
# 54  DEPUTY ASSISTANT TO PRESIDENT & DEPUTY STAFF S...
# 55     STAFF DIRECTOR FOR THE OFFICE OF SPEECHWRITING
# 56                                 ATTORNEY - ADVISOR
# 57                 SPECIAL ASSISTANT (SENATE LIAISON)
# 58  SPECIAL ASSISTANT TO THE PRESIDENT FOR PUBLIC ...
# 59                                 SENIOR CASE WORKER

# %%
wh_df.tail()
# Out:
#        year                name  gender    status    salary  pay_basis  \
# 10595  2020    Young,Stewart B.    Male  Employee  120000.0  Per Annum
# 10596  2020    Zadrozny,John A.    Male  Employee  158000.0  Per Annum
# 10597  2020      Zakaria,Hannah  Female  Employee   53000.0  Per Annum
# 10598  2020  Ziegler,Garrett M.    Male  Employee   53000.0  Per Annum
# 10599  2020  Zimmerman,Keith E.    Male  Employee   58200.0  Per Annum
#
#                                           position_title
# 10595  SPECIAL ASSISTANT TO THE PRESIDENT AND DIRECTO...
# 10596  DEPUTY ASSISTANT TO THE PRESIDENT AND ADVISOR ...
# 10597         ASSOCIATE LOGISTICS AND OPERATIONS MANAGER
# 10598                              SENIOR POLICY ANALYST
# 10599                                 ASSOCIATE DIRECTOR

# %% [markdown]
# ## Simple data analysis

# %%
wh_df.describe()
# Out:
#                year         salary
# count  10600.000000   10595.000000
# mean    2008.426132   75185.340632
# std        6.813933   40155.241737
# min     1997.000000       0.000000
# 25%     2002.000000   43600.000000
# 50%     2009.000000   61500.000000
# 75%     2014.000000  101957.000000
# max     2020.000000  239595.000000

# %%
year_2020_df = wh_df[wh_df.year.eq(2020)]   # Details on only rows where year=2020
year_2020_df.describe()
# Out:
#          year         salary
# count   412.0     407.000000
# mean   2020.0   97644.805897
# std       0.0   44131.788366
# min    2020.0       0.000000
# 25%    2020.0   58200.000000
# 50%    2020.0   86200.000000
# 75%    2020.0  135000.000000
# max    2020.0  190289.000000

# %%
only_females = wh_df[wh_df.gender.eq("Female")]
only_females.describe()  # Describing the dataset
# Out:
#               year         salary
# count  5595.000000    5594.000000
# mean   2008.001966   68432.746335
# std       6.872257   36311.596150
# min    1997.000000       0.000000
# 25%    2002.000000   42000.000000
# 50%    2008.000000   55575.000000
# 75%    2014.000000   89317.250000
# max    2020.000000  183000.000000

# %%
only_females.head(60)  # Displaying 60 rows of the dataset
# Out:
#     year                    name  gender    status    salary  pay_basis  \
# 0   1997          Abedin,Huma M.  Female  Employee   27500.0  Per Annum
# 1   1997          Abrams,Lori E.  Female  Employee   35000.0  Per Annum
# 3   1997     Allen,Jeannetta Pam  Female  Employee   22000.0  Per Annum
# 4   1997      Allison,Donna Tate  Female  Employee   27624.0  Per Annum
# 5   1997       Alston,Mildred C.  Female  Employee   47000.0  Per Annum
# 7   1997         Amador,Patricia  Female  Detailee   54629.0  Per Annum
# 9   1997           Anders,Brenda  Female  Employee   31000.0  Per Annum
# 10  1997      Anderson,Lori Lynn  Female  Employee   30000.0  Per Annum
# 13  1997        Bachman,Robin J.  Female  Employee   45000.0  Per Annum
# 14  1997    Baer,Christine Klima  Female  Employee   43442.0  Per Annum
# 16  1997        Bailey,Yvonne G.  Female  Employee   27964.0  Per Annum
# 18  1997      Balderston,Kris M.  Female  Detailee  108824.0  Per Annum
# 21  1997      Barclay,Barbara A.  Female  Employee   53598.0  Per Annum
# 22  1997    Barksdale,Antoinette  Female  Detailee   71011.0  Per Annum
# 23  1997       Barnes,Beverly L.  Female  Employee   90000.0  Per Annum
# 24  1997       Barry,Kathleen A.  Female  Employee   25000.0  Per Annum
# 26  1997        Bates,Melinda N.  Female  Employee   59000.0  Per Annum
# 27  1997          Bean,Eileen F.  Female  Employee   41866.0  Per Annum
# 29  1997   Bedwell,Wendy Lynette  Female  Employee   25897.0  Per Annum
# 31  1997    Bennett,Jacquelyn J.  Female  Employee   45000.0  Per Annum
# 33  1997         Berry,Marsha E.  Female  Employee   85000.0  Per Annum
# 34  1997         Beveridge,Susan  Female  Employee   31500.0  Per Annum
# 35  1997   Bianchi,Sarah Abigail  Female  Employee   40000.0  Per Annum
# 36  1997           Binns,Mary U.  Female  Employee   33792.0  Per Annum
# 37  1997           Bird,Debra D.  Female  Employee   42164.0  Per Annum
# 40  1997         Blunt,Shenna C.  Female  Employee   22500.0  Per Annum
# 45  1997          Bromberg,Emily  Female  Employee   80000.0  Per Annum
# 46  1997         Brophy,Susan A.  Female  Employee  110000.0  Per Annum
# 47  1997    Brown,Margueritte B.  Female  Detailee   83528.0  Per Annum
# 49  1997     Button,Katharine M.  Female  Employee   30000.0  Per Annum
# 50  1997       Byrd,Kimberley J.  Female  Employee   23305.0  Per Annum
# 51  1997      Cameron,Rebecca A.  Female  Employee   35000.0  Per Annum
# 52  1997     Campbell,Frances L.  Female  Employee   44719.0  Per Annum
# 53  1997      Canter,Virginia R.  Female  Employee   92000.0  Per Annum
# 55  1997    Capps,Laura Karolina  Female  Employee   34000.0  Per Annum
# 56  1997       Caramanica,Janice  Female  Detailee   56450.0  Per Annum
# 58  1997   Carter,Cheryl M. Cole  Female  Employee   85000.0  Per Annum
# 59  1997      Castleman,Helen S.  Female  Employee   28500.0  Per Annum
# 60  1997     Cattalini,Ann Marie  Female  Employee   40000.0  Per Annum
# 62  1997          Chirwa,Dawn M.  Female  Employee   92000.0  Per Annum
# 63  1997            Chow,Barbara  Female  Employee   89000.0  Per Annum
# 64  1997          Cicetti,Pamela  Female  Employee   60000.0  Per Annum
# 65  1997       Clarke,Senoria K.  Female  Detailee   64555.0  Per Annum
# 66  1997    Cleveland,Carolyn E.  Female  Employee   55130.0  Per Annum
# 67  1997     Cogdell,C. Patricia  Female  Employee   30000.0  Per Annum
# 69  1997          Conroy,Mary R.  Female  Detailee  113751.0  Per Annum
# 70  1997     Corbett,Julianne B.  Female  Employee   25000.0  Per Annum
# 71  1997  Cornelius,Catherine A.  Female  Employee   48000.0  Per Annum
# 72  1997      Costello,Brenda B.  Female  Employee   31000.0  Per Annum
# 73  1997      Cozart,Charlene C.  Female  Employee   60092.0  Per Annum
# 74  1997     Crable,Lynn Allison  Female  Employee   47471.0  Per Annum
# 75  1997         Craighead,Kelly  Female  Employee   58000.0  Per Annum
# 76  1997         Crisci,Michelle  Female  Employee   35000.0  Per Annum
# 77  1997          Croft,Caroline  Female  Detailee   98714.0  Per Annum
# 79  1997          Curiel,Carolyn  Female  Employee   90000.0  Per Annum
# 80  1997         Currie,Betty W.  Female  Employee   60000.0  Per Annum
# 81  1997         Curtis,Janet F.  Female  Employee   41866.0  Per Annum
# 82  1997         Cushing,Anna E.  Female  Employee   24000.0  Per Annum
# 83  1997          Cutler,Lynn G.  Female  Employee   99500.0  Per Annum
# 84  1997            Dale,Suzanne  Female  Employee   35000.0  Per Annum
#
#                                        position_title
# 0                                      OFFICE MANAGER
# 1                  DEPUTY DIRECTOR, WHITE HOUSE GIFTS
# 3                                     STAFF ASSISTANT
# 4                      WHITE HOUSE TELEPHONE OPERATOR
# 5           SPECIAL ASSISTANT PERSONAL CORRESPONDENCE
# 7                                  ATTORNEY - ADVISOR
# 9                                   RADIO COORDINATOR
# 10                   ASSISTANT TO THE PRESS SECRETARY
# 13                                         RESEARCHER
# 14                                  SPECIAL ASSISTANT
# 16                     WHITE HOUSE TELEPHONE OPERATOR
# 18  SPECIAL ASSISTANT TO THE PRESIDENT FOR CABINET...
# 21    ADMINISTRATIVE ASSISTANT TO THE STAFF SECRETARY
# 22                                 ATTORNEY - ADVISOR
# 23               SENIOR ADVISOR TO THE CHIEF OF STAFF
# 24                                    STAFF ASSISTANT
# 26  SPECIAL ASSISTANT TO THE PRESIDENT AND DIRECTO...
# 27  WHITE HOUSE TELEPHONE OPERATOR ASSISTANT SUPER...
# 29                      RECORDS MANAGEMENT TECHNICIAN
# 31                                  FINANCIAL MANAGER
# 33  DEPUTY ASSISTANT TO THE PRESIDENT & DIRECTOR O...
# 34                                 SENIOR CASE WORKER
# 35               ASSISTANT DIRECTOR FOR HEALTH POLICY
# 36                             CORRESPONDENCE ANALYST
# 37                                     OFFICE MANAGER
# 40                   ADMINISTRATIVE SUPPORT ASSISTANT
# 45  DEPUTY ASSISTANT TO THE PRESIDENT & DEPUTY DIR...
# 46  DEPUTY ASSISTANT TO THE PRESIDENT & DEPUTY DIR...
# 47                       ASSISTANT FOR CORRESPONDENCE
# 49  ASSISTANT TO THE CHIEF OF STAFF TO THE FIRST LADY
# 50                     WHITE HOUSE TELEPHONE OPERATOR
# 51                                    STAFF ASSISTANT
# 52                         SUPERVISOR DATA ENTRY UNIT
# 53                 ASSOCIATE COUNSEL TO THE PRESIDENT
# 55     STAFF DIRECTOR FOR THE OFFICE OF SPEECHWRITING
# 56                                 ATTORNEY - ADVISOR
# 58  SPECIAL ASSISTANT TO THE PRESIDENT FOR PUBLIC ...
# 59                                 SENIOR CASE WORKER
# 60                         SPECIAL EVENTS COORDINATOR
# 62                 ASSOCIATE COUNSEL TO THE PRESIDENT
# 63        SPECIAL ASSISTANT TO THE PRESIDENT - SENATE
# 64                                EXECUTIVE ASSISTANT
# 65                                 ATTORNEY - ADVISOR
# 66    ADMINISTRATIVE ASSISTANT TO THE STAFF SECRETARY
# 67             DIRECTOR WHITE HOUSE CONFERENCE CENTER
# 69                                     SEARCH MANAGER
# 70                          NEWS ANALYSIS COORDINATOR
# 71  SPECIAL ASSISTANT TO THE PRESIDENT AND DEPUTY ...
# 72                     ASSOCIATE DIRECTOR OF RESEARCH
# 73                  DEPUTY DIRECTOR OF AGENCY LIAISON
# 74           ASSISTANT DIRECTOR, PRESIDENTIAL SUPPORT
# 75  SPECIAL ASSISTANT TO THE PRESIDENT & DIRECTOR ...
# 76                    ASSISTANT TO THE SENIOR ADVISOR
# 77                                     SEARCH MANAGER
# 79  SPECIAL ASSISTANT TO THE PRESIDENT & SENIOR PR...
# 80                PERSONAL SECRETARY TO THE PRESIDENT
# 81                                  SPECIAL ASSISTANT
# 82                                             WRITER
# 83  DEPUTY ASSISTANT TO THE PRESIDENT & DEPUTY DIR...
# 84                                 ASSOCIATE DIRECTOR

# %% [markdown]
# ## Histogram

# %%
# %matplotlib inline

# %%
year_2020_df.salary.hist() # Plot histogram of the salaries

# %% [markdown]
# ## THE END
